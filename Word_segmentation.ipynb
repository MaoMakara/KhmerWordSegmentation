# %%
import Khmer_wordsegment

# %%
text = "អ្នកវិភាគគោលនយោបាយ និងអ្នកឃ្លាំមើលសង្គមភ្ញាក់ផ្អើលដែលលោកនាយករដ្ឋមន្រ្តី ហ៊ុន សែន នៅតែខ្វះភាពចាស់ទុំផ្នែកនយោបាយការទូតជាមួយប្រទេសមហាអំណាច ក្រោយលោកសរសេរសារឌឺដងដាក់សហរដ្ឋអាមេរិក និងសម្ព័ន្ធមិត្ត រឿងដកកងទ័ពចេញពីប្រទេសអាហ្វហ្គានីស្ថាន។"

# %%
sentence = Khmer_wordsegment.AngkorSegmentation(text)

# %%
d = sentence.check_words()

# %%
print(d)
# Out:
# ['អ្នកវិភាគ', 'គោលនយោបាយ', 'និង', 'អ្នកឃ្លាំមើល', 'សង្គម', 'ភ្ញាក់ផ្អើល', 'ដែល', 'លោកនាយករដ្ឋមន្រ្តី', 'ហ៊ុន', 'សែន', 'នៅតែ', 'ខ្វះ', 'ភាពចាស់ទុំ', 'ផ្នែក', 'នយោបាយ', 'ការទូត', 'ជាមួយ', 'ប្រទេស', 'មហាអំណាច', 'ក្រោយ', 'លោក', 'សរសេរ', 'សារ', 'ឌឺដង', 'ដាក់', 'សហរដ្ឋអាមេរិក', 'និង', 'សម្ព័ន្ធមិត្ត', 'រឿង', 'ដកកងទ័ព', 'ចេញពី', 'ប្រទេស', 'អាហ្វហ្គានីស្ថាន', '       ។']

# %%
sentence.show()
# Out:
# Original Text: អ្នកវិភាគគោលនយោបាយ និងអ្នកឃ្លាំមើលសង្គមភ្ញាក់ផ្អើលដែលលោកនាយករដ្ឋមន្រ្តី ហ៊ុន សែន នៅតែខ្វះភាពចាស់ទុំផ្នែកនយោបាយការទូតជាមួយប្រទេសមហាអំណាច ក្រោយលោកសរសេរសារឌឺដងដាក់សហរដ្ឋអាមេរិក និងសម្ព័ន្ធមិត្ត រឿងដកកងទ័ពចេញពីប្រទេសអាហ្វហ្គានីស្ថាន។
# Segment: ['អ្នកវិភាគ', 'គោលនយោបាយ', 'និង', 'អ្នកឃ្លាំមើល', 'សង្គម', 'ភ្ញាក់ផ្អើល', 'ដែល', 'លោកនាយករដ្ឋមន្រ្តី', 'ហ៊ុន', 'សែន', 'នៅតែ', 'ខ្វះ', 'ភាពចាស់ទុំ', 'ផ្នែក', 'នយោបាយ', 'ការទូត', 'ជាមួយ', 'ប្រទេស', 'មហាអំណាច', 'ក្រោយ', 'លោក', 'សរសេរ', 'សារ', 'ឌឺដង', 'ដាក់', 'សហរដ្ឋអាមេរិក', 'និង', 'សម្ព័ន្ធមិត្ត', 'រឿង', 'ដកកងទ័ព', 'ចេញពី', 'ប្រទេស', 'អាហ្វហ្គានីស្ថាន', '       ។']
# ZeroSpace : [អ្នកវិភាគ​គោលនយោបាយ​និង​អ្នកឃ្លាំមើល​សង្គម​ភ្ញាក់ផ្អើល​ដែល​លោកនាយករដ្ឋមន្រ្តី​ហ៊ុន​សែន​នៅតែ​ខ្វះ​ភាពចាស់ទុំ​ផ្នែក​នយោបាយ​ការទូត​ជាមួយ​ប្រទេស​មហាអំណាច​ក្រោយ​លោក​សរសេរ​សារ​ឌឺដង​ដាក់​សហរដ្ឋអាមេរិក​និង​សម្ព័ន្ធមិត្ត​រឿង​ដកកងទ័ព​ចេញពី​ប្រទេស​អាហ្វហ្គានីស្ថាន​       ។]
# Total Words: 34
